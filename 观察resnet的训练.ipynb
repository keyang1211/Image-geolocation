# %%
import pandas as pd

# %%
resnet=pd.read_csv("metrics.csv")

# %%
resnet.head(5)
# Out:
#       train_loss  step  epoch  100_accratio  the_val_loss  val_loss  \
# 0  640738.269407    49      0           NaN           NaN       NaN
# 1  606832.567116    99      0           NaN           NaN       NaN
# 2  594247.611308   149      0           NaN           NaN       NaN
# 3  638146.230562   199      0           NaN           NaN       NaN
# 4  608146.950841   249      0           NaN           NaN       NaN
#
#    2000_accratio  1000_accratio  500_accratio
# 0            NaN            NaN           NaN
# 1            NaN            NaN           NaN
# 2            NaN            NaN           NaN
# 3            NaN            NaN           NaN
# 4            NaN            NaN           NaN

# %%
resnet[(resnet["epoch"]== 11)&resnet["train_loss"].isnull()]
# Out:
#       train_loss    step  epoch  100_accratio  the_val_loss       val_loss  \
# 7327         NaN  361961     11      0.013399   4204.635254  537739.681916
# 7408         NaN  365961     11      0.013083   4201.728516  537105.965554
# 7489         NaN  369961     11      0.012677   4210.088379  538365.520005
# 7570         NaN  373961     11      0.012903   4207.649414  538030.414059
# 7651         NaN  377961     11      0.013399   4206.125488  537461.070571
# 7732         NaN  381961     11      0.012452   4194.739746  536100.305361
# 7813         NaN  385961     11      0.013128           NaN            NaN
# 7894         NaN  389961     11      0.013579   4211.675293  538328.990560
#
#       2000_accratio  1000_accratio  500_accratio
# 7327       0.425562       0.277407      0.141297
# 7408       0.430344       0.279482      0.141794
# 7489       0.420509       0.275738      0.138861
# 7570       0.421907       0.274159      0.137643
# ...

# %%
resnet[(resnet["epoch"]== 12)&resnet["train_loss"].isnull()]
# Out:
#       train_loss    step  epoch  100_accratio  the_val_loss       val_loss  \
# 7986         NaN  394503     12      0.015249   4110.859375  525716.672180
# 8067         NaN  398503     12      0.014707   4112.625977  525531.017041
# 8148         NaN  402503     12      0.013624           NaN            NaN
# 8229         NaN  406503     12      0.012993   4110.878418  525186.037164
#
#       2000_accratio  1000_accratio  500_accratio
# 7986       0.439231       0.287422      0.148110
# 8067       0.443292       0.293242      0.149824
# 8148       0.438961       0.282595      0.142110
# 8229       0.436479       0.283407      0.145448

# %%
resnet[(resnet["epoch"]== 0)&resnet["train_loss"].isnull()]
# Out:
#      train_loss   step  epoch  100_accratio  the_val_loss       val_loss  \
# 80          NaN   3999      0      0.006406   4707.165039  601614.937051
# 161         NaN   7999      0      0.009113   4614.905762  590176.929448
# 242         NaN  11999      0      0.009925   4563.610840  583246.856342
# 323         NaN  15999      0      0.006902   4587.508789  586355.014167
# 404         NaN  19999      0      0.008256   4549.852539  581167.998721
# 485         NaN  23999      0      0.006587   4520.167480  577540.216188
# 566         NaN  27999      0      0.010106   4522.723633  578003.634740
# 647         NaN  31999      0      0.010331   4468.072266  571197.069085
#
#      2000_accratio  1000_accratio  500_accratio
# 80        0.311152       0.154967      0.079717
# 161       0.343860       0.176171      0.080529
# 242       0.353424       0.189795      0.091491
# 323       0.337499       0.182126      0.087792
# 404       0.346883       0.178923      0.077596
# ...

# %%
resnet[(resnet["epoch"]== 10)&resnet["train_loss"].isnull()]
# Out:
#       train_loss    step  epoch  100_accratio  the_val_loss       val_loss  \
# 6668         NaN  329419     10      0.014527   4176.562988  534001.014658
# 6749         NaN  333419     10      0.013489   4225.687988  540207.046374
# 6830         NaN  337419     10      0.013218   4188.765625  535654.238890
# 6911         NaN  341419     10      0.012767   4197.298340  536408.674953
# 6992         NaN  345419     10      0.013624   4196.506836  536497.392994
# 7073         NaN  349419     10      0.012361   4194.701660  536199.042337
# 7154         NaN  353419     10      0.014346   4173.261719  533165.894903
# 7235         NaN  357419     10      0.012632   4218.334961  539361.817209
#
#       2000_accratio  1000_accratio  500_accratio
# 6668       0.427817       0.279166      0.140891
# 6749       0.421140       0.270279      0.133583
# 6830       0.420148       0.274384      0.139944
# 6911       0.425968       0.271677      0.134034
# ...
